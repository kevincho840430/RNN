# %% [markdown]
# # 使用conv1d來實踐股票預測
# 前面我們使用LSTM來建立股票預測模型，現在換成使用conv1d來實驗看看效果。

# %%
import numpy as np
import tensorflow.keras as keras
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %% [markdown]
# ### Step 0. Loading dataset

# %%
tesla_stocks = pd.read_csv('Data/tesla_stocks.csv')

# %%
tesla_stocks.head()
# Out:
#        Date    Open    High     Low   Close   Volume
# 0  4-Aug-14  234.38  240.50  233.27  238.52  5967406
# 1  5-Aug-14  237.47  242.99  235.69  238.49  5388581
# 2  6-Aug-14  238.90  251.42  238.58  248.93  9249265
# 3  7-Aug-14  250.12  256.69  249.12  252.39  7478926
# 4  8-Aug-14  251.16  251.76  246.50  248.13  5099061

# %%
data_to_use = tesla_stocks['Close'].values

# %%
print('Total number of days in the dataset: {}'.format(len(data_to_use)))
# Out:
# Total number of days in the dataset: 756

# %% [markdown]
# ### Step 1. Data preprocessing

# %% [markdown]
# #### Step 1.1 Scaling data

# %%
scaler = StandardScaler()

# %%
scaled_dataset = scaler.fit_transform(data_to_use.reshape(-1, 1))

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

tesla_stocks.Date = pd.to_datetime(tesla_stocks.Date)
plt.figure(figsize=(12,7), frameon=False, facecolor='brown', edgecolor='blue')
plt.title('Scaled TESLA stocks from August 2014 to August 2017')
plt.xlabel('Days')
plt.ylabel('Scaled value of stocks')
plt.plot(tesla_stocks.Date, scaled_dataset, label='Stocks data')
plt.legend()
plt.show()

# %%
def window_data(data, window_size):
    X = []
    y = []
    i = 0
    while (i + window_size) <= len(data) - 1:
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
        i += 1
    assert len(X) == len(y)
    return X, y

# %% [markdown]
# #### Step 1.2 Windowing the dataset
# 使用windows分割資料，產生新的dataset

# %%
window_size = 7

X, y = window_data(scaled_dataset, window_size)

# %% [markdown]
# #### Step 1.3 Creating Training and Testing sets
# 將新的dataset分割成 Training和Testing

# %%
X_train  = np.array(X[:700])
y_train = np.array(y[:700])

X_test = np.array(X[700:])
y_test = np.array(y[700:])

print("X_train size: {}".format(X_train.shape))
print("y_train size: {}".format(y_train.shape))
print("X_test size: {}".format(X_test.shape))
print("y_test size: {}".format(y_test.shape))
# Out:
# X_train size: (700, 7, 1)
# y_train size: (700, 1)
# X_test size: (49, 7, 1)
# y_test size: (49, 1)

# %% [markdown]
# ### Let's create the Conv1D

# %%
X_train.shape
# Out:
# (700, 7, 1)

# %% [markdown]
# <img src='images/Conv1d_stock_Sequential.png'/>

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input,Dense, Activation, Conv1D, Flatten


model = Sequential()
# inputs = Input(shape=(window_size,))
model.add(Conv1D(input_shape=(window_size, 1), filters = 16, kernel_size=3, strides=1, \
                 activation='relu'))
model.add(Conv1D(filters = 16, kernel_size=3, strides=1, \
                 activation='relu'))
model.add(Flatten()) #由於前面兩個conv1D的Kerner size都是3，所以原本長度是7的資料會變成3，而channels為16，所以一起攤平變成48
model.add(Dense(1)) #輸出一個值
print(model.input_shape) #可以把輸入的型態秀出來
model.summary()
# Out:
# (None, 7, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 5, 16)             64
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 3, 16)             784
# _________________________________________________________________
# flatten (Flatten)            (None, 48)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 49
# =================================================================
# Total params: 897
# Trainable params: 897
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = keras.optimizers.Adam(lr=0.001, decay=1e-6, clipvalue=5)

model.compile( loss='mse', optimizer=opt, metrics=['mse'] )
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))#,
# Out:
# Train on 700 samples, validate on 49 samples
# Epoch 1/100
# 700/700 [==============================] - 1s 2ms/sample - loss: 0.4689 - mse: 0.4689 - val_loss: 3.5260 - val_mse: 3.5260
# Epoch 2/100
# 700/700 [==============================] - 0s 66us/sample - loss: 0.0955 - mse: 0.0955 - val_loss: 0.2932 - val_mse: 0.2932
# Epoch 3/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0538 - mse: 0.0538 - val_loss: 0.1121 - val_mse: 0.1121
# Epoch 4/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0519 - mse: 0.0519 - val_loss: 0.1405 - val_mse: 0.1405
# Epoch 5/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0504 - mse: 0.0504 - val_loss: 0.1142 - val_mse: 0.1142
# Epoch 6/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0486 - mse: 0.0486 - val_loss: 0.1064 - val_mse: 0.1064
# Epoch 7/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0471 - mse: 0.0471 - val_loss: 0.0941 - val_mse: 0.0941
# Epoch 8/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0449 - mse: 0.0449 - val_loss: 0.1081 - val_mse: 0.1081
# Epoch 9/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0438 - mse: 0.0438 - val_loss: 0.0990 - val_mse: 0.0990
# Epoch 10/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0855 - val_mse: 0.0855
# Epoch 11/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0383 - mse: 0.0383 - val_loss: 0.0869 - val_mse: 0.0869
# Epoch 12/100
# 700/700 [==============================] - 0s 62us/sample - loss: 0.0365 - mse: 0.0365 - val_loss: 0.0892 - val_mse: 0.0892
# Epoch 13/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0358 - mse: 0.0358 - val_loss: 0.0909 - val_mse: 0.0909
# Epoch 14/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0336 - mse: 0.0336 - val_loss: 0.0742 - val_mse: 0.0742
# Epoch 15/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0329 - mse: 0.0329 - val_loss: 0.0710 - val_mse: 0.0710
# Epoch 16/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0316 - mse: 0.0316 - val_loss: 0.0694 - val_mse: 0.0694
# Epoch 17/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0760 - val_mse: 0.0760
# Epoch 18/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0294 - mse: 0.0294 - val_loss: 0.0755 - val_mse: 0.0755
# Epoch 19/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0282 - mse: 0.0282 - val_loss: 0.0747 - val_mse: 0.0747
# Epoch 20/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0277 - mse: 0.0277 - val_loss: 0.0721 - val_mse: 0.0721
# Epoch 21/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0270 - mse: 0.0270 - val_loss: 0.0703 - val_mse: 0.0703
# Epoch 22/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0266 - mse: 0.0266 - val_loss: 0.1008 - val_mse: 0.1008
# Epoch 23/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0259 - mse: 0.0259 - val_loss: 0.0608 - val_mse: 0.0608
# Epoch 24/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0253 - mse: 0.0253 - val_loss: 0.0610 - val_mse: 0.0610
# Epoch 25/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0249 - mse: 0.0249 - val_loss: 0.0613 - val_mse: 0.0613
# Epoch 26/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0248 - mse: 0.0248 - val_loss: 0.0616 - val_mse: 0.0616
# Epoch 27/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0239 - mse: 0.0239 - val_loss: 0.0686 - val_mse: 0.0686
# Epoch 28/100
# 700/700 [==============================] - 0s 62us/sample - loss: 0.0239 - mse: 0.0239 - val_loss: 0.2346 - val_mse: 0.2346
# Epoch 29/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0241 - mse: 0.0241 - val_loss: 0.1320 - val_mse: 0.1320
# Epoch 30/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0690 - val_mse: 0.0690
# Epoch 31/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0557 - val_mse: 0.0557
# Epoch 32/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0545 - val_mse: 0.0545
# Epoch 33/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0228 - mse: 0.0228 - val_loss: 0.0563 - val_mse: 0.0563
# Epoch 34/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0651 - val_mse: 0.0651
# Epoch 35/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0219 - mse: 0.0219 - val_loss: 0.0590 - val_mse: 0.0590
# Epoch 36/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0523 - val_mse: 0.0523
# Epoch 37/100
# 700/700 [==============================] - 0s 66us/sample - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0539 - val_mse: 0.0539
# Epoch 38/100
# 700/700 [==============================] - 0s 67us/sample - loss: 0.0216 - mse: 0.0216 - val_loss: 0.1018 - val_mse: 0.1018
# Epoch 39/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 40/100
# 700/700 [==============================] - 0s 62us/sample - loss: 0.0206 - mse: 0.0206 - val_loss: 0.0540 - val_mse: 0.0540
# Epoch 41/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0207 - mse: 0.0207 - val_loss: 0.0506 - val_mse: 0.0506
# Epoch 42/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0515 - val_mse: 0.0515
# Epoch 43/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0210 - mse: 0.0210 - val_loss: 0.0512 - val_mse: 0.0512
# Epoch 44/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0205 - mse: 0.0205 - val_loss: 0.0575 - val_mse: 0.0575
# Epoch 45/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0485 - val_mse: 0.0485
# Epoch 46/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0807 - val_mse: 0.0807
# Epoch 47/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0196 - mse: 0.0196 - val_loss: 0.0649 - val_mse: 0.0649
# Epoch 48/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0508 - val_mse: 0.0508
# Epoch 49/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0484 - val_mse: 0.0484
# Epoch 50/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0479 - val_mse: 0.0479
# Epoch 51/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0187 - mse: 0.0187 - val_loss: 0.0624 - val_mse: 0.0624
# Epoch 52/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0191 - mse: 0.0191 - val_loss: 0.0491 - val_mse: 0.0491
# Epoch 53/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0483 - val_mse: 0.0483
# Epoch 54/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.1092 - val_mse: 0.1092
# Epoch 55/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0465 - val_mse: 0.0465
# Epoch 56/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0893 - val_mse: 0.0893
# Epoch 57/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 58/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0850 - val_mse: 0.0850
# Epoch 59/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0485 - val_mse: 0.0485
# Epoch 60/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0190 - mse: 0.0190 - val_loss: 0.0463 - val_mse: 0.0463
# Epoch 61/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0580 - val_mse: 0.0580
# Epoch 62/100
# 700/700 [==============================] - 0s 65us/sample - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0448 - val_mse: 0.0448
# Epoch 63/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0517 - val_mse: 0.0517
# Epoch 64/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0663 - val_mse: 0.0663
# Epoch 65/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0930 - val_mse: 0.0930
# Epoch 66/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0873 - val_mse: 0.0873
# Epoch 67/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0189 - mse: 0.0189 - val_loss: 0.0998 - val_mse: 0.0998
# Epoch 68/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0471 - val_mse: 0.0471
# Epoch 69/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0517 - val_mse: 0.0517
# Epoch 70/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0449 - val_mse: 0.0449
# Epoch 71/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0179 - mse: 0.0179 - val_loss: 0.0454 - val_mse: 0.0454
# Epoch 72/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0559 - val_mse: 0.0559
# Epoch 73/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0624 - val_mse: 0.0624
# Epoch 74/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0496 - val_mse: 0.0496
# Epoch 75/100
# 700/700 [==============================] - 0s 62us/sample - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0786 - val_mse: 0.0786
# Epoch 76/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0700 - val_mse: 0.0700
# Epoch 77/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0443 - val_mse: 0.0443
# Epoch 78/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0677 - val_mse: 0.0677
# Epoch 79/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0742 - val_mse: 0.0742
# Epoch 80/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0541 - val_mse: 0.0541
# Epoch 81/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0181 - mse: 0.0181 - val_loss: 0.0480 - val_mse: 0.0480
# Epoch 82/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0178 - mse: 0.0178 - val_loss: 0.1104 - val_mse: 0.1104
# Epoch 83/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0636 - val_mse: 0.0636
# Epoch 84/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0953 - val_mse: 0.0953
# Epoch 85/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.1753 - val_mse: 0.1753
# Epoch 86/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0185 - mse: 0.0185 - val_loss: 0.0707 - val_mse: 0.0707
# Epoch 87/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0183 - mse: 0.0183 - val_loss: 0.0700 - val_mse: 0.0700
# Epoch 88/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0182 - mse: 0.0182 - val_loss: 0.0486 - val_mse: 0.0486
# Epoch 89/100
# 700/700 [==============================] - 0s 64us/sample - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0625 - val_mse: 0.0625
# Epoch 90/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0558 - val_mse: 0.0558
# Epoch 91/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0463 - val_mse: 0.0463
# Epoch 92/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0184 - mse: 0.0184 - val_loss: 0.0609 - val_mse: 0.0609
# Epoch 93/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0178 - mse: 0.0178 - val_loss: 0.0809 - val_mse: 0.0809
# Epoch 94/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0178 - mse: 0.0178 - val_loss: 0.1206 - val_mse: 0.1206
# Epoch 95/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0467 - val_mse: 0.0467
# Epoch 96/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0622 - val_mse: 0.0622
# Epoch 97/100
# 700/700 [==============================] - 0s 62us/sample - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0477 - val_mse: 0.0477
# Epoch 98/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0624 - val_mse: 0.0624
# Epoch 99/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0501 - val_mse: 0.0501
# Epoch 100/100
# 700/700 [==============================] - 0s 63us/sample - loss: 0.0186 - mse: 0.0186 - val_loss: 0.0493 - val_mse: 0.0493

# %%
#Training set預測結果
training_set_pred = np.array([])

training_set_pred = model.predict(X_train)

# %%
#Testing set預測結果

testing_set_pred = model.predict(X_test)

# %%
#把資料放到list裡面準備畫圖
#因為我們是用前七天預測第8天股價，故前七天設為None
training = [None]*window_size
for i in range(len(X_train)):
    training.append(training_set_pred[i])
testing = [None] * (window_size + len(X_train))
testing_loss = 0
for i in range(len(X_test)):
    testing.append(testing_set_pred[i])
    training.append(None)
    testing_loss += (testing_set_pred[i] - y_test[i])**2
print('testing_loss:', testing_loss / len(X_test))
# Out:
# testing_loss: [0.0492849]

# %% [markdown]
# ### Plotting predictions from the network

# %%
plt.figure(figsize=(16, 7))
plt.plot(tesla_stocks.Date, scaled_dataset, label='Original data')
plt.plot(tesla_stocks.Date, training, label='Training data')
plt.plot(tesla_stocks.Date, testing, label='Testing data')
plt.legend()
plt.show()
