# %% [markdown]
# # OpenCV 教學

# %% [markdown]
# ## Reading and writing image
# 在做圖像處理之時，首先需要先把圖片讀取進來可用 `cv2.imread()` 這個function讀取
# <br />由於是在hub上執行的關係，無法執行視窗畫面，因此改採用Matplotlib畫出圖片

# %% [markdown]
# Matplotlib 顯示圖片的方式也很簡單，只要呼叫 imshow 就可以了，但是由於 OpenCV 讀取進來的圖片會以 BGR 的方式儲存三個顏色的 channel，如果直接把 OpenCV 讀入的圖片放進 Matplotlib 來顯示，就會出現類似這樣的顏色錯誤問題

# %%
#import the libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2

#內嵌圖畫
# %matplotlib inline

#reading the image 
image = cv2.imread('index.png')

#做色彩轉換
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

#plotting the image
plt.imshow(image)
 
#saving image
#須將其轉回BGR格式才會是正確的顏色
image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
cv2.imwrite('./output/test_write.jpg',image)
# Out:
# True

# %% [markdown]
# ### 圖檔格式
#
# OpenCV 的 cv2.imread 在讀取圖片時，可以在第二個參數指定圖片的格式，可用的選項有三種：
#
# `cv2.IMREAD_COLOR`
# 此為預設值，這種格式會讀取 RGB 三個 channels 的彩色圖片，而忽略透明度的 channel。
# `cv2.IMREAD_GRAYSCALE`
# 以灰階的格式來讀取圖片。
# <br />`cv2.IMREAD_UNCHANGED`
# 讀取圖片中所有的 channels，包含透明度的 channel。<br />

# %% [markdown]
# ## 轉灰階
# 我們知道一圖像有紅色,綠色,藍色三個channel,灰階則只有一個,轉灰階可幫助降維訓練資料

# %%
#import the required libraries 
img_2 = cv2.imread('Lenna.png') 

#converting image to Gray scale 
gray_image = cv2.cvtColor(img_2, cv2.COLOR_BGR2GRAY)

#plotting the grayscale image
plt.imshow(gray_image,cmap='gray')

cv2.imwrite('./output/Lenna_gray.png',gray_image)
# Out:
# True

# %% [markdown]
# # 基本圖型繪製
# <br />`cv2.line(影像, 開始座標, 結束座標, 顏色, 線條寬度)`

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = np.zeros((512,512,3),np.uint8)#生成一个空彩色图像
cv2.line(img,(0,0),(511,511),(155,155,155),5)
plt.imshow(img,'brg')

# %% [markdown]
# <br />`cv2.rectangle(影像, 頂點座標, 對向頂點座標, 顏色, 線條寬度)`

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = np.zeros((512,512,3),np.uint8)#生成一个空彩色图像
cv2.rectangle(img,(20,20),(411,411),(55,255,155),5)
plt.imshow(img,'brg')

# %% [markdown]
# <br />`cv2.circle(影像, 圓心座標, 半徑, 顏色, 線條寬度)`
# <br />這裡的線條寬度參數若設定為正的值，則代表正常的線條寬度，而若設定為負的值，則代表畫實心的圓圈。

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = np.zeros((512,512,3),np.uint8)#生成一个空彩色图像
cv2.circle(img,(200,200),100,(55,255,155),5)#修改最后一个参数
plt.imshow(img,'brg')

# %% [markdown]
# <br />`cv2.putText(影像, 文字, 座標, 字型, 大小, 顏色, 線條寬度, 線條種類)`
# <br />這裡的座標是指文字的左下角座標點，大小則是代表字型的縮放比例（例如 1.5 就代表放大 1.5 倍）。最後一項線條種類參數可以指定如何繪製線條，若想要有反鋸齒（anti-aliasing）的效果，可設定為 cv2.LINE_AA。這項參數也可以省略不寫，若省略的話預設值為 cv2.LINE_8。`

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
name_list = ['We are X','YOSHIKI','HIDE','PATA','TAIJI','HEATH','SUGIZO']
img = np.zeros((512,512,3),np.uint8)#生成一个空陣列圖像
cv2.rectangle(img,(20,20),(411,411),(55,255,155),5)
cv2.putText(img, name_list[0], (40, 60), cv2.FONT_HERSHEY_TRIPLEX,1, (0, 255, 255), 2, cv2.LINE_AA)
cv2.putText(img, name_list[1], (40, 120), cv2.FONT_HERSHEY_PLAIN,2, (0, 255, 255), 3, cv2.LINE_AA)
cv2.putText(img, name_list[2], (40, 160), cv2.FONT_HERSHEY_DUPLEX,1, (0, 255, 255), 3, cv2.LINE_AA)
cv2.putText(img, name_list[3], (40, 200), cv2.FONT_HERSHEY_COMPLEX,1, (0, 255, 255),3, cv2.LINE_AA)
cv2.putText(img, name_list[4], (40, 240), cv2.FONT_HERSHEY_TRIPLEX,1, (0, 255, 255), 3, cv2.LINE_AA)
cv2.putText(img, name_list[5], (40, 280), cv2.FONT_HERSHEY_SCRIPT_SIMPLEX,1, (0, 255, 255), 3, cv2.LINE_AA)
cv2.putText(img, name_list[6], (40, 320), cv2.FONT_HERSHEY_SCRIPT_COMPLEX,1, (0, 255, 255), 3, cv2.LINE_AA)

plt.imshow(img,'brg')

# %% [markdown]
# ## 小練習請將Lenna的臉匡出並顯示名字Lenna
# 匡座標((20,20),(180,180))

# %% [markdown]
# # Resize
# - 當我們拿到dataset時通常需要先將所有的圖片轉化成同一個大小，才能開始訓練模型。
# <br/> `cv2.resize`function可很直覺的

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
#reading the image 
image = cv2.imread('hide.jpg') 
#converting image to size (100,100,3) 
smaller_image = cv2.resize(image,(100,100)) 
cv2.imwrite('./output/hide_resize.png',smaller_image)
#plot the resized image
smaller_image = cv2.cvtColor(smaller_image, cv2.COLOR_BGR2RGB)
plt.imshow(smaller_image)

# %%
#查看shape是否有變化
print(image.shape)
print(smaller_image.shape)

# %% [markdown]
# # Rotation
# - 當本身資料不夠或者是想增加多樣性的時候可使用此方法生成更多樣本來訓練我們的深度學習模型。
# - 旋轉是最常用且易於實現的數據增強技術之一。 顧名思義，它涉及以任意角度旋轉圖像並為其提供與原始圖像相同的標籤。

# %%
#importing the required libraries 
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 

image = cv2.imread('oneokrock.jpg') 
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
rows,cols = image.shape[:2] 
#(col/2,rows/2) is the center of rotation for the image 
# M is the cordinates of the center 
M = cv2.getRotationMatrix2D((cols/2,rows/2),180,1) 
dst = cv2.warpAffine(image,M,(cols,rows)) 

titles = ['Original Image','Rotation']
images = [image, dst]

plt.figure(figsize=(16,16))

for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # image translation
# - 圖像轉換可用於向模型添加移位不變性，因為通過平移我們可以更改圖像中對象的位置，從而為模型提供更多變化
# - 輸入圖像中位置（x，y）處出現的對像被移位到新位置（X，Y）：
# - X = x + dx
# - Y = y + dy

# %%
#importing the required libraries 
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 
#reading the image
image = cv2.imread('hide.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#shifting the image 100 pixels in both dimensions
M = np.float32([[1,0,-100],[0,1,-100]]) 
dst = cv2.warpAffine(image,M,(cols,rows)) 

titles = ['Original Image','Translation']
images = [image, dst]

plt.figure(figsize=(16,16))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # Image Threshold
# - 間單的定義如下：
# if Image(x,y) > threshold , Image(x,y) = 1
#     otherswise, Image(x,y) = 0
# - Thresholding can only be applied to grayscale images
# - 圖像閾值處理的簡單應用可以將圖像分成前景和背景。
#
# - 說明：https://docs.opencv.org/3.4/d7/d4d/tutorial_py_thresholding.html

# %%
#importing the required libraries 
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 

#here 0 means that the image is loaded in gray scale format
gray_image = cv2.imread('JR.jpg',0)

ret,thresh_binary = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)
ret,thresh_binary_inv = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY_INV)
ret,thresh_trunc = cv2.threshold(gray_image,127,255,cv2.THRESH_TRUNC)
ret,thresh_tozero = cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO)
ret,thresh_tozero_inv = cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO_INV)

#DISPLAYING THE DIFFERENT THRESHOLDING STYLES
names = ['Oiriginal Image','BINARY','THRESH_BINARY_INV','THRESH_TRUNC','THRESH_TOZERO','THRESH_TOZERO_INV']
images = gray_image,thresh_binary,thresh_binary_inv,thresh_trunc,thresh_tozero,thresh_tozero_inv

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(names[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %% [markdown]
# # Adaptive Thresholding
# - 有時候由於拍照時光線不均，所以影像每個區域的灰階值基準不同，這時很難找到一個閾值能適用整張影像，然後得到良好的二值化結果，這時我們可以將影像分成幾個區域，每個區域有各自的閾值，再分別將各個區域進行二值化，OpenCV用adaptiveThreshold()函式來進行此作法。

# %%
#import the libraries
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

#ADAPTIVE THRESHOLDING
gray_image = cv2.imread('JR.jpg',0)

ret,thresh_global = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)
#here 11 is the pixel neighbourhood that is used to calculate the threshold value
thresh_mean = cv2.adaptiveThreshold(gray_image,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)

thresh_gaussian = cv2.adaptiveThreshold(gray_image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)

names = ['Original Image','Global Thresholding','Adaptive Mean Threshold','Adaptive Gaussian Thresholding']
images = [gray_image,thresh_global,thresh_mean,thresh_gaussian]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(names[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %% [markdown]
# # Edge Detection
# - Edge detection邊緣偵測是Computer vision中重要的步驟，它讓電腦能準確的抓取圖素中的物體
# - 邊緣和物體間的邊界並不等同，邊緣指的是圖像中像素的值有突變的地方，而物體間的邊界指的是現實場景中的存在於物體之間的邊界。有可能有邊緣的地方並非邊界，也有可能邊界的地方並無邊緣。
# - Edge detection可用於圖像分割，甚至可用於圖像銳化。

# %%
#import the required libraries
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline
#read the image
image = cv2.imread('snake.jpg') 
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#calculate the edges using Canny edge algorithm
edges = cv2.Canny(image,100,200) 
#plot the edges

titles = ['Original Image','Canny']
images = [image, edges]

plt.figure(figsize=(16,16))
for i in range(2):
    plt.subplot(1,2,i+1),plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # Image Contours
# - Contours(輪廓)是點或線段的閉合曲線，表示圖像中對象的邊界。 輪廓基本上是圖像中對象的形狀。
# - 與邊緣不同，輪廓不是圖像的一部分。 相反，它們是對應於圖像中對象形狀的點和線段的抽象集合。
# - 我們可以使用輪廓來計算圖像中的對像數量，根據形狀對對象進行分類，或者從圖像中選擇特定形狀的對象。

# %%
#importing the required libraries 
import numpy as np 
import cv2 
import matplotlib.pyplot as plt 
# %matplotlib inline 
image = cv2.imread('snake.jpg') 
#converting RGB image to Binary 
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) 
ret,thresh = cv2.threshold(gray_image,127,255,0) 
#calculate the contours from binary image
im,contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE) 
with_contours = cv2.drawContours(image,contours,-1,(0,255,0),3) 
plt.imshow(with_contours)

# %% [markdown]
# # calcHist (像素值分佈直方圖)
# - OpenCV 的 calcHist 函數可用來計算直方圖的數值
# - cv2.calcHist(影像, 通道, 遮罩, 區間數量, 數值範圍)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 讀取圖檔
img = cv2.imread('gazette.jpg')

# 轉為灰階圖片
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 畫出直方圖
plt.hist(gray.ravel(), 256, [0, 256])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('gazette.jpg')

# 畫出 RGB 三種顏色的分佈圖
color = ('b','g','r')
for i, col in enumerate(color):
  histr = cv2.calcHist([img],[i],None,[256],[0, 256])
  plt.plot(histr, color = col)
  plt.xlim([0, 256])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 讀取圖檔
img = cv2.imread('gazette.jpg')

# 轉為灰階圖片
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 建立圖形遮罩
mask = np.zeros(gray.shape, np.uint8)
mask[300:780, 300:1620] = 255

# 計算套用遮罩後的圖形
masked_gray = cv2.bitwise_and(gray, gray, mask = mask)

# 以原圖計算直方圖
hist_full = cv2.calcHist([img], [0], None, [256], [0, 256])

# 以套用遮罩後的圖計算直方圖
hist_mask = cv2.calcHist([img], [0], mask, [256], [0, 256])

# 繪製結果
plt.subplot(221), plt.imshow(gray, 'gray')
plt.subplot(222), plt.imshow(mask, 'gray')
plt.subplot(223), plt.imshow(masked_gray, 'gray')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.xlim([0,256])

plt.show()

# %% [markdown]
# # Feature Matching
# - opencv內部提供圖像特徵匹配的function
# - 可用此function 找出圖片內部相似的部分

# %%
import numpy as np
import cv2

img = cv2.imread('gazette.jpg')
img2 = cv2.imread('reita.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

#特徴量
detector = cv2.ORB_create()
kp1, des1 = detector.detectAndCompute(gray, None)
kp2, des2 = detector.detectAndCompute(gray2, None)

#比较器
bf = cv2.BFMatcher(cv2.NORM_HAMMING)


# 载入特征点
matches = bf.match(des1, des2)
matches = sorted(matches, key = lambda x:x.distance)

# 表示结果
h1, w1, c1 = img.shape[:3]
h2, w2, c2 = img2.shape[:3]
height = max([h1,h2])
width = w1 + w2
out = np.zeros((height, width, 3), np.uint8)
cv2.drawMatches(img, kp1, img2, kp2, matches[:50],out, flags=0)
plt.imshow(out)

# %% [markdown]
# # Face detection
# - OpenCV支持基於haar cascade的對象檢測。 Haar級聯是基於機器學習的分類器，可以計算圖像中的邊緣，線條等不同的特徵。 然後，這些分類器使用多個正樣本和負樣本進行訓練。
# - 此處提供一個基於opencv的簡易臉部偵測實作
# https://www.analyticsvidhya.com/blog/2018/12/introduction-face-detection-video-deep-learning-python/

# %%
import numpy as np
import cv2
import os
from matplotlib import pyplot as plt

#讀取眼睛與臉部的已經學習後的分類器
face_cascade = cv2.CascadeClassifier("../opencv/data/haarcascades/haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("../opencv/data/haarcascades/haarcascade_eye.xml")


image = cv2.imread('jason.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    image = cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

plt.figure(figsize=(8,8))
plt.imshow(image)
